# %% [markdown]
# # Amazon Data Analysis

# %% [markdown]
# ## Importing the essential packages

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing amazon data

# %%
amazon=pd.read_csv("amazon.csv")

# %%
amazon.drop(1282,axis=0,inplace=True)

# %% [markdown]
# ## Finding the best Products

# %%
amazon_best=pd.DataFrame({"Product":amazon["product_name"],"Rating":amazon["rating"],"Rating_Count":amazon["rating_count"],"Category":amazon["category"]})

# %%
amazon_best
# Out:
#                                                 Product Rating Rating_Count  \
# 0     Wayona Nylon Braided USB to Lightning Fast Cha...    4.2        24269
# 1     Ambrane Unbreakable 60W / 3A Fast Charging 1.5...      4        43994
# 2     Sounce Fast Phone Charging Cable & Data Sync U...    3.9         7928
# 3     boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...    4.2        94363
# 4     Portronics Konnect L 1.2M Fast Charging 3A 8 P...    4.2        16905
# ...                                                 ...    ...          ...
# 1460  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...      4         1090
# 1461  Prestige Delight PRWO Electric Rice Cooker (1 ...    4.1         4118
# 1462  Bajaj Majesty RX10 2000 Watts Heat Convector R...    3.6          468
# 1463  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...      4         8031
# 1464  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...    4.3         6987
#
#                                                Category
# ...

# %%
amazon_best["Rating_Count"] = amazon_best["Rating_Count"].str.replace("[,]", "")
# Out:
# C:\Users\prana\AppData\Local\Temp\ipykernel_11356\3119184482.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   amazon_best["Rating_Count"] = amazon_best["Rating_Count"].str.replace("[,]", "")

# %%
amazon_best.dropna(inplace=True)

# %%
amazon_best["Rating_Count"] = amazon_best["Rating_Count"].astype(int)

# %%
amazon_best["Rating"] = amazon_best["Rating"].str.replace("[.]", "")
# Out:
# C:\Users\prana\AppData\Local\Temp\ipykernel_11356\1366243082.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   amazon_best["Rating"] = amazon_best["Rating"].str.replace("[.]", "")

# %%
amazon_best["Rating"] = amazon_best["Rating"].str.replace("[|]", "30")
# Out:
# C:\Users\prana\AppData\Local\Temp\ipykernel_11356\2907396271.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   amazon_best["Rating"] = amazon_best["Rating"].str.replace("[|]", "30")

# %%
amazon_best["Rating"] = amazon_best["Rating"].astype(int)

# %%
amazon_best["Rating"] = amazon_best["Rating"].replace({1:10,2:20,3:30,4:40,5:50})

# %% [markdown]
# ## Top products ranked by Rating

# %%
amazon_best[amazon_best["Rating"] > 46]
# Out:
#                                                 Product  Rating  Rating_Count  \
# 174   Syncwire LTG to USB Cable for Fast Charging Co...      50             5
# 249   Sony Bravia 164 cm (65 inches) 4K Ultra HD Sma...      47          5935
# 459   Spigen EZ Fit Tempered Glass Screen Protector ...      47          7779
# 775   Amazon Basics Wireless Mouse | 2.4 GHz Connect...      50            23
# 1145  Swiffer Instant Electric Water Heater Faucet T...      48         53803
# 1201  Oratech Coffee Frother electric, milk frother ...      48            28
# 1223  FIGMENT Handheld Milk Frother Rechargeable, 3-...      47          1729
# 1226  Zuvexa USB Rechargeable Electric Foam Maker - ...      47            54
# 1275  Multifunctional 2 in 1 Electric Egg Boiling St...      47          2300
# 1299  Instant Pot Air Fryer, Vortex 2QT, Touch Contr...      48          3964
# 1388  Campfire Spring Chef Prolix Instant Portable W...      47          2591
#
# ...

# %% [markdown]
# ## Top products ranked by Rating_Count

# %%
amazon_best[amazon_best["Rating_Count"] > 300000]
# Out:
#                                                Product  Rating  Rating_Count  \
# 12   AmazonBasics Flexible Premium HDMI Cable (Blac...      44        426973
# 47   Amazon Basics High-Speed HDMI Cable, 6 Feet - ...      44        426973
# 65   Amazon Basics High-Speed HDMI Cable, 6 Feet (2...      44        426973
# 352  boAt Bassheads 100 in Ear Wired Earphones with...      41        363713
# 370  Redmi 9 Activ (Carbon Black, 4GB RAM, 64GB Sto...      41        313836
# 371  Redmi 9A Sport (Coral Green, 2GB RAM, 32GB Sto...      41        313836
# 400  boAt Bassheads 100 in Ear Wired Earphones with...      41        363713
# 473  Redmi 9A Sport (Carbon Black, 2GB RAM, 32GB St...      41        313832
# 566  Redmi 9A Sport (Coral Green, 3GB RAM, 32GB Sto...      41        313832
# 584  boAt BassHeads 100 in-Ear Wired Headphones wit...      41        363711
# 684  AmazonBasics Flexible Premium HDMI Cable (Blac...      44        426972
#
# ...

# %% [markdown]
# ## Sales on Categories

# %% [markdown]
# C - Computers&Accessories <br>
# H - Home&Kitchen <br>
# E - Electronics <br>
# M - MusicalInstruments <br>
# O - OfficeProducts <br>
# T - Toys&Games <br>

# %%
amazon_best["Category"].str[0:2]
amazon_best["Category"].hist();

# %%
amazon_best[amazon_best["Rating_Count"] < 10]
# Out:
#                                                 Product  Rating  Rating_Count  \
# 174   Syncwire LTG to USB Cable for Fast Charging Co...      50             5
# 299   WANBO X1 Pro (Upgraded) | Native 1080P Full HD...      45             7
# 1070  Lifelong LLQH925 Dyno Quartz Heater 2 Power se...      38             4
# 1121  C (DEVICE) Lint Remover for Woolen Clothes, El...      37             6
# 1222  Kitchenwell Multipurpose Portable Electronic D...      43             7
# 1293  Melbon VM-905 2000-Watt Room Heater (ISI Certi...      46             9
# 1309  Khaitan ORFin Fan heater for Home and kitchen-...      20             2
# 1344  Longway Blaze 2 Rod Quartz Room Heater (White,...      37             4
# 1374  KNYUC MART Mini Electric Handy Room Heater Com...      33             8
# 1385  VAPJA® Portable Mini Juicer Cup Blender USB Re...      36             4
# 1459  NGI Store 2 Pieces Pet Hair Removers for Your ...      31             2
#
# ...

# %%
amazon_best[amazon_best["Rating"] < 30]
# Out:
#                                                 Product  Rating  Rating_Count  \
# 545   SHREENOVA ID116 Plus Bluetooth Fitness Smart W...      28            87
# 1243  Personal Size Blender, Portable Blender, Batte...      23            13
# 1286  MR. BRAND Portable USB Juicer Electric USB Jui...      28           109
# 1309  Khaitan ORFin Fan heater for Home and kitchen-...      20             2
# 1356  Green Tales Heat Seal Mini Food Sealer-Impulse...      26            24
# 1449  IONIX Tap filter Multilayer | Activated Carbon...      29           159
#
#                                                Category
# 545         Electronics|WearableTechnology|SmartWatches
# 1243  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...
# 1286  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...
# 1309  Home&Kitchen|Heating,Cooling&AirQuality|RoomHe...
# 1356  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...
# 1449  Home&Kitchen|Kitchen&HomeAppliances|WaterPurif...

# %%
amazon_price=pd.DataFrame({"Product":amazon["product_name"],"Discounted_Price":amazon["discounted_price"],"Actual_Price":amazon["actual_price"],"Category":amazon["category"],"Discount_Percentage":amazon["discount_percentage"]})

# %%
amazon_price
# Out:
#                                                 Product Discounted_Price  \
# 0     Wayona Nylon Braided USB to Lightning Fast Cha...             ₹399
# 1     Ambrane Unbreakable 60W / 3A Fast Charging 1.5...             ₹199
# 2     Sounce Fast Phone Charging Cable & Data Sync U...             ₹199
# 3     boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...             ₹329
# 4     Portronics Konnect L 1.2M Fast Charging 3A 8 P...             ₹154
# ...                                                 ...              ...
# 1460  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...             ₹379
# 1461  Prestige Delight PRWO Electric Rice Cooker (1 ...           ₹2,280
# 1462  Bajaj Majesty RX10 2000 Watts Heat Convector R...           ₹2,219
# 1463  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...           ₹1,399
# 1464  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...           ₹2,863
#
#      Actual_Price                                           Category  \
# ...

# %%
amazon_price["Discounted_Price"] = amazon_price["Discounted_Price"].str.replace("[,]", "")
# Out:
# C:\Users\prana\AppData\Local\Temp\ipykernel_11356\3081365792.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   amazon_price["Discounted_Price"] = amazon_price["Discounted_Price"].str.replace("[,]", "")

# %%
amazon_price["Discounted_Price"] = amazon_price["Discounted_Price"].str.replace("[₹]", "")
# Out:
# C:\Users\prana\AppData\Local\Temp\ipykernel_11356\3253760282.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   amazon_price["Discounted_Price"] = amazon_price["Discounted_Price"].str.replace("[₹]", "")

# %%
amazon_price["Discounted_Price"] = amazon_price["Discounted_Price"].str.replace("[.]", "")
# Out:
# C:\Users\prana\AppData\Local\Temp\ipykernel_11356\3755020356.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   amazon_price["Discounted_Price"] = amazon_price["Discounted_Price"].str.replace("[.]", "")

# %%
amazon_price["Discounted_Price"] = amazon_price["Discounted_Price"].astype(int)
